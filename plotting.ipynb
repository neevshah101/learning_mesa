# %%
# import mesa_reader to make its classes accessible
import mesa_reader as mr

# make a MesaData object from a history file
h = mr.MesaData('tutorial/LOGS/history.data')
# Out:
# /home/neevshah/anaconda3/lib/python3.12/site-packages/mesa_reader-0.3.0-py3.12.egg/mesa_reader/__init__.py:240: SyntaxWarning: invalid escape sequence '\+'
# /home/neevshah/anaconda3/lib/python3.12/site-packages/mesa_reader-0.3.0-py3.12.egg/mesa_reader/__init__.py:247: SyntaxWarning: invalid escape sequence '\s'
# /home/neevshah/anaconda3/lib/python3.12/site-packages/mesa_reader-0.3.0-py3.12.egg/mesa_reader/__init__.py:240: SyntaxWarning: invalid escape sequence '\+'
# /home/neevshah/anaconda3/lib/python3.12/site-packages/mesa_reader-0.3.0-py3.12.egg/mesa_reader/__init__.py:247: SyntaxWarning: invalid escape sequence '\s'

# %%
import matplotlib.pyplot as plt
import scienceplots
import numpy as np
import pandas as pd

plt.style.use(['science'])

# %%
ss = mr.MesaData('tutorial_single_star/LOGS/history.data')
bs = mr.MesaData('tutorial_binary_star/LOGS1/history.data')
mass_1 = mr.MesaData('mass_1/LOGS/history.data')

# %%
m_15 = pd.read_table('tutorial_single_star/LOGS/history.data', skiprows=5, sep='\s+')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_119978/2034775300.py:1: SyntaxWarning: invalid escape sequence '\s'
#   m_15 = pd.read_table('tutorial_single_star/LOGS/history.data', skiprows=5, sep='\s+')

# %%
m_15
# Out:
#      model_number  num_zones      star_age    log_dt  star_mass  log_xmstar  \
# 0               1        472  1.000000e-05 -5.000000       15.0   34.474597
# 1               5        474  7.441600e-05 -4.683275       15.0   34.474597
# 2              10        489  2.595868e-04 -4.287369       15.0   34.474597
# 3              15        474  7.203511e-04 -3.891463       15.0   34.474597
# 4              20        489  1.866880e-03 -3.495556       15.0   34.474597
# ..            ...        ...           ...       ...        ...         ...
# 136           675       1725  1.238127e+07  3.545166       15.0   34.474597
# 137           680       1778  1.239105e+07  2.762269       15.0   34.474597
# 138           685       1789  1.239592e+07  3.055929       15.0   34.474597
# 139           690       1808  1.240607e+07  3.451835       15.0   34.474597
# 140           692       1828  1.241015e+07  3.258015       15.0   34.474597
#
# ...

# %%
plt.plot(np.log10(mass_1.Teff),mass_1.log_L, label = r'$1M_{\odot}$')
# plt.plot(np.log10(ss.Teff),ss.log_L, label = r'$15M_{\odot}$')

plt.ylabel('Luminosity')
plt.xlabel('Temperature')
# plt.ylim(4.2,4.8)
plt.legend()
plt.ticklabel_format(style = 'plain')
# invert the x-axis
plt.gca().invert_xaxis()
plt.show()

plt.plot(np.log10(ss.Teff),ss.log_L, label = r'$15M_{\odot}$')
plt.scatter(np.log10(ss.Teff[58:80]),ss.log_L[58:80], color = 'red', s = 10)

plt.ylabel('Luminosity')
plt.xlabel('Temperature')
plt.ylim(4.2,4.8)
plt.legend()
plt.ticklabel_format(style = 'plain')
# invert the x-axis
plt.gca().invert_xaxis()

# %%
plt.plot(mass_1.star_age,10**(mass_1.log_R), label = r'$1M_{\odot}$')
plt.ylim(0.8,2)
plt.xlim(1e7,1e10)

plt.show()

plt.plot(ss.star_age,10**(ss.log_R), label = r'$15M_{\odot}$')
plt.ylim(0.1,20)
plt.xlim(1e7,1.1e7)

plt.show()

# %%
age = ss.data('star_age')
radius = ss.data('R')
log_L = ss.data('log_L')
T_eff = ss.data('Teff')
center_h1 = ss.data('center_h1')
center_he4 = ss.data('center_he4')
center_c12 = ss.data('center_c12')
center_o16 = ss.data('center_o16')

age_bs = bs.data('star_age')
radius_bs = bs.data('R')
log_L_bs = bs.data('log_L')
T_eff_bs = bs.data('Teff')
center_h1_bs = bs.data('center_h1')
center_he4_bs = bs.data('center_he4')
center_c12_bs = bs.data('center_c12')
center_o16_bs = bs.data('center_o16')

# %%
condition = age > 1e5
condition_bs = age_bs > 0
plt.plot(np.log10(T_eff[condition]),log_L[condition], label = r'$15M_{\odot}$')
plt.plot(np.log10(T_eff_bs[condition_bs]),log_L_bs[condition_bs], label = r'$15M_{\odot}$ in binary')
# plt.xscale('log')
# plt.yscale('log')
plt.ylabel('Luminosity')
plt.xlabel('Temperature')
plt.ylim(4.2,4.8)
plt.legend()
plt.ticklabel_format(style = 'plain')
# invert the x-axis
plt.gca().invert_xaxis()

# %%
bs.bulk_names
# Out:
# ('model_number',
#  'num_zones',
#  'star_age',
#  'log_dt',
#  'star_mass',
#  'log_xmstar',
#  'log_abs_mdot',
#  'mass_conv_core',
#  'conv_mx1_top',
#  'conv_mx1_bot',
#  'conv_mx2_top',
#  'conv_mx2_bot',
#  'mx1_top',
#  'mx1_bot',
#  'mx2_top',
#  'mx2_bot',
#  'log_LH',
#  'log_LHe',
#  'log_LZ',
#  'log_Lnuc',
#  'pp',
#  'cno',
#  'tri_alpha',
#  'epsnuc_M_1',
#  'epsnuc_M_2',
#  'epsnuc_M_3',
#  'epsnuc_M_4',
#  'epsnuc_M_5',
#  'epsnuc_M_6',
#  'epsnuc_M_7',
#  'epsnuc_M_8',
#  'he_core_mass',
#  'co_core_mass',
#  'one_core_mass',
#  'fe_core_mass',
#  'neutron_rich_core_mass',
#  'log_Teff',
#  'log_L',
#  'log_R',
#  'log_g',
#  'v_div_csound_surf',
#  'log_cntr_P',
#  'log_cntr_Rho',
#  'log_cntr_T',
#  'center_mu',
#  'center_ye',
#  'center_abar',
#  'center_h1',
#  'center_he4',
#  'center_c12',
#  'center_o16',
#  'surface_c12',
#  'surface_o16',
#  'total_mass_h1',
#  'total_mass_he4',
#  'num_retries',
#  'num_iters',
#  'model_number_1',
#  'age',
# ...

# %%
plt.plot(bs.age,bs.period_days)
plt.xlim(1.14e7,1.144e7)
plt.ylim(98,101)
#plt.xscale('log')
#plt.yscale('log')
plt.show()

plt.plot(bs.age,bs.star_1_mass, label = 'Star 1')
plt.xlim(1.14e7,1.144e7)

plt.plot(bs.age,bs.star_2_mass, label = 'Star 2')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Mass')
# plt.xlim(1.14e7,1.144e7)
p#lt.ylim(98,101)
#plt.xscale('log')
#plt.yscale('log')

plt.show()

plt.plot(bs.age,bs.log_R, label = 'Star 1')
plt.xlim(1.14e7,1.15e7)
plt.yscale('log')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Radius')
# Out:
# Text(0, 0.5, 'Radius')

# %%
age = h.data('star_age')
radius = h.data('R')
log_L = h.data('log_L')
T_eff = h.data('Teff')
center_h1 = h.data('center_h1')
center_he4 = h.data('center_he4')
center_c12 = h.data('center_c12')
center_o16 = h.data('center_o16')

# %%
import matplotlib.pyplot as plt
import scienceplots
import numpy as np

plt.style.use(['science'])

# %%
plt.scatter(age,radius, label = r'$15M_{\odot}$', s = 1)
plt.xscale('log')
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.xlim(1e3,1e5)
plt.show()

plt.plot(age,radius, label = r'$15M_{\odot}$')
plt.xscale('log')
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.xlim(1e6,1e7)
plt.ylim(1,20)
# Out:
# (1.0, 20.0)

# %%
h.bulk_names
# Out:
# ('model_number',
#  'num_zones',
#  'star_age',
#  'log_dt',
#  'star_mass',
#  'log_xmstar',
#  'log_abs_mdot',
#  'mass_conv_core',
#  'conv_mx1_top',
#  'conv_mx1_bot',
#  'conv_mx2_top',
#  'conv_mx2_bot',
#  'mx1_top',
#  'mx1_bot',
#  'mx2_top',
#  'mx2_bot',
#  'log_LH',
#  'log_LHe',
#  'log_LZ',
#  'log_Lnuc',
#  'pp',
#  'cno',
#  'tri_alpha',
#  'epsnuc_M_1',
#  'epsnuc_M_2',
#  'epsnuc_M_3',
#  'epsnuc_M_4',
#  'epsnuc_M_5',
#  'epsnuc_M_6',
#  'epsnuc_M_7',
#  'epsnuc_M_8',
#  'he_core_mass',
#  'co_core_mass',
#  'one_core_mass',
#  'fe_core_mass',
#  'neutron_rich_core_mass',
#  'log_Teff',
#  'log_L',
#  'log_R',
#  'log_g',
#  'v_div_csound_surf',
#  'log_cntr_P',
#  'log_cntr_Rho',
#  'log_cntr_T',
#  'center_mu',
#  'center_ye',
#  'center_abar',
#  'center_h1',
#  'center_he4',
#  'center_c12',
#  'center_o16',
#  'surface_c12',
#  'surface_o16',
#  'total_mass_h1',
#  'total_mass_he4',
#  'num_retries',
#  'num_iters')

# %%
condition = age > 10**4.5
plt.plot(np.log10(T_eff[condition]),log_L[condition], label = r'$15M_{\odot}$')
# plt.xscale('log')
# plt.yscale('log')
plt.ylabel('Luminosity')
plt.xlabel('Temperature')
plt.ylim(4.2,4.8)
plt.legend()
plt.ticklabel_format(style = 'plain')
# invert the x-axis
plt.gca().invert_xaxis()

# %%
plt.plot(age,center_h1, label = r'Central $\rm H$')
plt.plot(age,center_he4, label = r'Central $\rm{He}_4$')
plt.plot(age,center_c12, label = r'Central $\rm{C}_{12}$')
plt.plot(age,center_o16, label = r'Central $\rm{O}_{16}$')
plt.xscale('log')
#plt.yscale('log')
plt.xlabel('Age')
plt.ylabel('Mass Fraction')
plt.xlim(10**7,10**(7.1))
plt.legend()
plt.show()

# %%
p = mr.MesaProfileIndex('tutorial/LOGS/profiles.index')

# %%
# load entire LOG directory information
l = mr.MesaLogDir('tutorial/LOGS')
# grab the last profile
p = l.profile_data()

# this works even if you only have logRho and logT!
plt.loglog(p.Rho, p.T)
plt.xlabel("Density")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
import os

logs_dir = os.path.join('tutorial_single_star', 'LOGS')

# %run useful_mesa_functions.py {logs_dir}
# Out:
# /home/neevshah/PhD/learning_mesa/useful_mesa_functions.py:13: SyntaxWarning: invalid escape sequence '\s'
#   skiprows=5, sep='\s+')
# /home/neevshah/PhD/learning_mesa/useful_mesa_functions.py:20: SyntaxWarning: invalid escape sequence '\s'
#
# /home/neevshah/PhD/learning_mesa/useful_mesa_functions.py:54: SyntaxWarning: invalid escape sequence '\s'
#   return prof

# %%
plot_HR()

# %%
plot_composition(7)

# %%
# %run useful_mesa_functions.py
# Out:
# /home/neevshah/PhD/learning_mesa/useful_mesa_functions.py:13: SyntaxWarning: invalid escape sequence '\s'
#   skiprows=5, sep='\s+')
# /home/neevshah/PhD/learning_mesa/useful_mesa_functions.py:18: SyntaxWarning: invalid escape sequence '\s'
#   skiprows=1, sep='\s+')
# /home/neevshah/PhD/learning_mesa/useful_mesa_functions.py:62: SyntaxWarning: invalid escape sequence '\s'
#   skiprows=5, sep='\s+')

# %%
logs_dir = os.path.join('tutorial_single_star', 'LOGS')

plot_HR(logs_dir)

logs_dir = os.path.join('mass_1', 'LOGS')

plot_HR(logs_dir)

logs_dir = os.path.join('mass_1p6', 'LOGS')

plot_HR(logs_dir)

# %%
df = load_history_file(logs_dir)

# %%
df.columns
# Out:
# Index(['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass',
#        'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top',
#        'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot',
#        'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp',
#        'cno', 'tri_alpha', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3',
#        'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8',
#        'he_core_mass', 'co_core_mass', 'one_core_mass', 'fe_core_mass',
#        'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g',
#        'v_div_csound_surf', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T',
#        'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4',
#        'center_c12', 'center_o16', 'surface_c12', 'surface_o16',
#        'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_iters'],
#       dtype='object')

# %%
plt.plot(df['star_age'],df['log_LHe'], label = 'He')
plt.plot(df['star_age'],df['log_LH'], label = 'H')
plt.legend()
plt.ylabel(r'$\rm logL$')
ax = plt.twinx()
ax.plot(df['star_age'],df['log_R'], color = 'red')
plt.xscale('log')
plt.xlim(1e9,3e9)
plt.xlabel('Age')
plt.ylabel('logR')
plt.show()

# %%
logs_dir = os.path.join('tutorial_binary_star', 'LOGS1')
df = load_history_file(logs_dir)

# %%
df.columns
# Out:
# Index(['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass',
#        'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top',
#        'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot',
#        'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp',
#        'cno', 'tri_alpha', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3',
#        'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8',
#        'he_core_mass', 'co_core_mass', 'one_core_mass', 'fe_core_mass',
#        'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g',
#        'v_div_csound_surf', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T',
#        'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4',
#        'center_c12', 'center_o16', 'surface_c12', 'surface_o16',
#        'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_iters',
#        'model_number.1', 'age', 'period_days', 'binary_separation', 'v_orb_1',
# ...

# %%
plt.plot(df['star_age'], df['star_1_mass'], label = 'Star 1')
plt.plot(df['star_age'], df['star_2_mass'], label = 'Star 2')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Mass')
plt.legend()
plt.show()

plt.plot(df['star_age'], df['period_days'], label = 'Star 1')
plt.xlim(1.07e7,1.08e7)
plt.ylim(18,22)
plt.xlabel('Age')
plt.ylabel('Period')
# plt.legend()
plt.show()

plt.plot(df['star_age'], df['Jdot'], label = 'Star 1')
plt.xlim(1.05e7,1.15e7)
plt.xlabel('Age')
plt.ylabel('Jdot')
# plt.legend()
plt.show()

plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], df['rl_1'], label = 'Roche Lobe')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.show()

# %%
plot_HR(logs_dir)

# %%
df[df.columns[78:88]]
# Out:
#              J_orb          Jdot  jdot_mb       jdot_gr       jdot_ml  \
# 0     1.725889e+54 -2.525901e+33      0.0 -2.525901e+33  0.000000e+00
# 1     1.725889e+54 -2.525901e+33      0.0 -2.525901e+33  0.000000e+00
# 2     1.725889e+54 -2.525901e+33      0.0 -2.525901e+33  0.000000e+00
# 3     1.725889e+54 -2.525901e+33      0.0 -2.525901e+33  0.000000e+00
# 4     1.725889e+54 -2.525901e+33      0.0 -2.525901e+33  0.000000e+00
# ...            ...           ...      ...           ...           ...
# 1108  1.017408e+54 -5.516091e+36      0.0 -1.745061e+30 -5.516089e+36
# 1109  1.017408e+54 -6.160546e+36      0.0 -1.745057e+30 -6.160544e+36
# 1110  1.017408e+54 -6.861984e+36      0.0 -1.745053e+30 -6.861982e+36
# 1111  1.017408e+54 -7.650364e+36      0.0 -1.745049e+30 -7.650363e+36
# 1112  1.017408e+54 -8.457907e+36      0.0 -1.745044e+30 -8.457905e+36
#
#       jdot_ls  jdot_missing_wind  extra_jdot  donor_index  point_mass_index
# ...

# %%
logs_dir = os.path.join('tutorial_binary_star', 'LOGS11')
df = load_history_file(logs_dir)

# %%
plot_HR(logs_dir)

# %%
plt.plot(df['star_age'], df['star_1_mass'], label = 'Star 1')
plt.plot(df['star_age'], df['star_2_mass'], label = 'Star 2')
plt.plot(df['star_age'], df['star_1_mass'] + df['star_2_mass'], label = 'Total')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Mass')
plt.legend()
plt.show()

plt.plot(df['star_age'], df['period_days'], label = 'Star 1')
plt.xlim(1.07e7,1.08e7)
plt.ylim(17,30)
plt.xlabel('Age')
plt.ylabel('Period')
# plt.legend()
plt.show()

plt.plot(df['star_age'], df['Jdot'], label = 'Star 1')
plt.xlim(1.05e7,1.15e7)
plt.xlabel('Age')
plt.ylabel('Jdot')
# plt.legend()
plt.show()

plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], df['rl_1'], label = 'Roche Lobe')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.show()

# %%
df[df.columns[78:88]]
# Out:
#              J_orb          Jdot       jdot_mb       jdot_gr       jdot_ml  \
# 0     1.725889e+54 -2.525901e+33  0.000000e+00 -2.525901e+33  0.000000e+00
# 1     1.725889e+54 -2.525901e+33  0.000000e+00 -2.525901e+33  0.000000e+00
# 2     1.725889e+54 -2.525901e+33  0.000000e+00 -2.525901e+33  0.000000e+00
# 3     1.725889e+54 -2.525901e+33  0.000000e+00 -2.525901e+33  0.000000e+00
# 4     1.725889e+54 -2.525901e+33  0.000000e+00 -2.525901e+33  0.000000e+00
# ...            ...           ...           ...           ...           ...
# 3372  1.663526e+54 -1.622576e+35 -1.888575e+13 -1.882946e+30 -1.622557e+35
# 3373  1.663526e+54 -1.622576e+35 -1.888575e+13 -1.882946e+30 -1.622557e+35
# 3374  1.663526e+54 -1.622576e+35 -1.888575e+13 -1.882946e+30 -1.622557e+35
# 3375  1.663526e+54 -1.622576e+35 -1.888575e+13 -1.882946e+30 -1.622557e+35
# 3376  1.663526e+54 -1.622576e+35 -1.888575e+13 -1.882946e+30 -1.622557e+35
#
# ...

# %%
np.max(df['star_1_mass'] +  df['star_2_mass']) - np.min(df['star_1_mass'] +  df['star_2_mass'])
# Out:
# 1.7242594587776345

# %%
# Out:
# Index(['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass',
#        'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top',
#        'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot',
#        'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp',
#        'cno', 'tri_alpha', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3',
#        'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8',
#        'he_core_mass', 'co_core_mass', 'one_core_mass', 'fe_core_mass',
#        'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g',
#        'v_div_csound_surf', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T',
#        'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4',
#        'center_c12', 'center_o16', 'surface_c12', 'surface_o16',
#        'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_iters',
#        'model_number.1', 'age', 'period_days', 'binary_separation', 'v_orb_1',
# ...

# %%
options[0]
# Out:
# ['lg_mtransfer_rate', 'lg_mstar_dot_1', 'lg_mstar_dot_2']

# %%
options = ['lg_mtransfer_rate', 'lg_mstar_dot_1', 'lg_mstar_dot_2']
    #    'lg_system_mdot_1', 'lg_system_mdot_2', 'lg_wind_mdot_1',
    #    'lg_wind_mdot_2']

# plt.figure(figsize = (4,4))

# for o in options:
#     plt.plot(df['star_age'], df[o], label = o, lw = 1)

plt.plot(df['star_age'],10**df[options[1]]/10**df[options[2]], label = f'{options[1]}/{options[2]}')

plt.xlim(1.06e7,1.11e7)
# plt.ylim(-9,-2)
plt.xlabel('Age')
plt.ylabel('Ratio of Mass Loss Rate')
plt.legend()

plt.twinx().plot(df['star_age'], df['star_1_mass']/df['star_2_mass'],color = 'red')
plt.ylabel('Mass Ratio',color = 'red')
plt.show()

# plt.plot(df['star_age'], df['star_1_mass']/df['star_2_mass'])
# plt.xlim(1.07e7,1.08e7)
# plt.xlabel('Age')
# plt.ylabel('Mass ratio')
# plt.show()

# %%
options = ['Jdot','jdot_ml']

for o in options:
    
    plt.plot(df['star_age'], df[o], label = o, lw = 1)

plt.xlim(1.07e7,1.08e7)
# plt.ylim(-9,-2)
plt.xlabel('Age')
plt.ylabel('jdot')
plt.legend()

# %%
plt.plot(df['star_age'], df['jdot_missing_wind'])
plt.ylabel('jdot_missing_wind')
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %%
df[['lg_mstar_dot_1','lg_mstar_dot_2']]
# Out:
#       lg_mstar_dot_1  lg_mstar_dot_2
# 0         -99.000000      -99.000000
# 1         -99.000000      -99.000000
# 2         -99.000000      -99.000000
# 3         -99.000000      -99.000000
# 4         -99.000000      -99.000000
# ...              ...             ...
# 3372       -8.755197       -8.884465
# 3373       -8.755197       -8.884465
# 3374       -8.755197       -8.884465
# 3375       -8.755197       -8.884465
# 3376       -8.755197       -8.884465
#
# [3377 rows x 2 columns]

# %%
10**df[options[1]]/10**df[options[2]]
# Out:
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.000000
#           ...
# 3372    1.346691
# 3373    1.346691
# 3374    1.346691
# 3375    1.346691
# 3376    1.346691
# Length: 3377, dtype: float64

# %%
logs_dir = os.path.join('tutorial_binary_star', 'LOGS12')
df = load_history_file(logs_dir)

# %%
plt.plot(df['star_age'], df['star_1_mass'], label = 'Star 1')
plt.plot(df['star_age'], df['star_2_mass'], label = 'Star 2')
plt.plot(df['star_age'], df['star_1_mass'] + df['star_2_mass'], label = 'Total')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Mass')
plt.legend()
plt.show()

plt.plot(df['star_age'], df['period_days'], label = 'Star 1')
plt.xlim(1.07e7,1.08e7)
plt.ylim(17,30)
plt.xlabel('Age')
plt.ylabel('Period')
# plt.legend()
plt.show()

plt.plot(df['star_age'], df['Jdot'], label = 'Star 1')
plt.xlim(1.05e7,1.15e7)
plt.xlabel('Age')
plt.ylabel('Jdot')
# plt.legend()
plt.show()

plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], df['rl_1'], label = 'Roche Lobe')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.show()

# %%
logs_dir = os.path.join('tutorial_binary_star', 'LOGS12')
df = load_history_file(logs_dir)

# %%
plt.plot(df['star_age'], df['star_1_mass'], label = 'Star 1')
plt.plot(df['star_age'], df['star_2_mass'], label = 'Star 2')
plt.plot(df['star_age'], df['star_1_mass'] + df['star_2_mass'], label = 'Total')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Mass')
plt.legend()
plt.show()

plt.plot(df['star_age'], df['period_days'], label = 'Star 1')
plt.xlim(1.07e7,1.08e7)
plt.ylim(17,30)
plt.xlabel('Age')
plt.ylabel('Period')
# plt.legend()
plt.show()

plt.plot(df['star_age'], df['Jdot'], label = 'Star 1')
plt.xlim(1.05e7,1.15e7)
plt.xlabel('Age')
plt.ylabel('Jdot')
# plt.legend()
plt.show()

plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], df['rl_1'], label = 'Roche Lobe')
plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.show()

# %%
options = ['lg_mstar_dot_1', 'lg_mstar_dot_2']
    #    'lg_system_mdot_1', 'lg_system_mdot_2', 'lg_wind_mdot_1',
    #    'lg_wind_mdot_2']

plt.figure(figsize = (4,4))

for o in options:
    plt.plot(df['star_age'], df[o], label = o, lw = 1)

plt.ylim(-4,-2.5)
plt.xlim(1.073e7,1.077e7)
# Out:
# (10730000.0, 10770000.0)

# %%
plot_HR(logs_dir)

# %%
import os
logs_dir = os.path.join('tutorial_binary_star', 'LOGS13')
df = load_history_file(logs_dir)

# %%
plot_HR(logs_dir)

# %%
plt.plot(df['star_age'], df['star_1_mass'], label = 'Star 1')
plt.plot(df['star_age'], df['star_2_mass'], label = 'Star 2')
plt.plot(df['star_age'], df['star_1_mass'] + df['star_2_mass'], label = 'Total')
# plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Mass')
plt.legend()
plt.show()

plt.plot(df['star_age'], df['period_days'], label = 'Star 1')
# plt.xlim(1.07e7,1.08e7)
# plt.ylim(17,30)
plt.xlabel('Age')
plt.ylabel('Period')
# plt.legend()
plt.show()

plt.plot(df['star_age'], df['Jdot'], label = 'Star 1')
# plt.xlim(1.05e7,1.15e7)
plt.xlabel('Age')
plt.ylabel('Jdot')
# plt.legend()
plt.show()

plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], df['rl_1'], label = 'Roche Lobe')
# plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['model_number', 'num_zones', 'star_age', 'log_dt', 'star_mass',
#        'log_xmstar', 'log_abs_mdot', 'mass_conv_core', 'conv_mx1_top',
#        'conv_mx1_bot', 'conv_mx2_top', 'conv_mx2_bot', 'mx1_top', 'mx1_bot',
#        'mx2_top', 'mx2_bot', 'log_LH', 'log_LHe', 'log_LZ', 'log_Lnuc', 'pp',
#        'cno', 'tri_alpha', 'epsnuc_M_1', 'epsnuc_M_2', 'epsnuc_M_3',
#        'epsnuc_M_4', 'epsnuc_M_5', 'epsnuc_M_6', 'epsnuc_M_7', 'epsnuc_M_8',
#        'he_core_mass', 'co_core_mass', 'one_core_mass', 'fe_core_mass',
#        'neutron_rich_core_mass', 'log_Teff', 'log_L', 'log_R', 'log_g',
#        'v_div_csound_surf', 'log_cntr_P', 'log_cntr_Rho', 'log_cntr_T',
#        'center_mu', 'center_ye', 'center_abar', 'center_h1', 'center_he4',
#        'center_c12', 'center_o16', 'surface_c12', 'surface_o16',
#        'total_mass_h1', 'total_mass_he4', 'num_retries', 'num_iters',
#        'model_number.1', 'age', 'period_days', 'binary_separation', 'v_orb_1',
# ...

# %%
import os
logs_dir = os.path.join('tutorial_binary_star', 'LOGS14')
df = load_history_file(logs_dir)

# %%
plot_HR(logs_dir)

# %%
plt.plot(df['star_age'], df['star_1_mass'], label = 'Star 1')
plt.plot(df['star_age'], df['star_2_mass'], label = 'Star 2')
plt.plot(df['star_age'], df['star_1_mass'] + df['star_2_mass'], label = 'Total')
# plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Mass')
plt.legend()
plt.show()

plt.plot(df['star_age'], df['period_days'], label = 'Star 1')
# plt.xlim(1.07e7,1.08e7)
# plt.ylim(17,30)
plt.xlabel('Age')
plt.ylabel('Period')
# plt.legend()
plt.show()

plt.plot(df['star_age'], df['Jdot'], label = 'Star 1')
# plt.xlim(1.05e7,1.15e7)
plt.xlabel('Age')
plt.ylabel('Jdot')
# plt.legend()
plt.show()

plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], 10**df['log_R'], label = 'Star 1')
plt.plot(df['star_age'], df['rl_1'], label = 'Roche Lobe')
# plt.xlim(1.07e7,1.08e7)
plt.xlabel('Age')
plt.ylabel('Radius')
plt.legend()
plt.show()

# %%
logs_dir = os.path.join('tutorial_binary_star', 'LOGS15')
df = load_history_file(logs_dir)

plot_HR(logs_dir)

# %%
profs = get_profiles(logs_dir)

# %%
for p in profs:
    plt.plot(p["mass"],p['x_mass_fraction_H'])
